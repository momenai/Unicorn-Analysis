# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("CB-Insights_Global-Unicorn-Club_2023.xlsx",skiprows=2)

# %%
df = df.drop(df.columns[7:], axis=1)
df = df.drop(df.columns[[0]], axis=1)

# %%
df.head()
# Out:
#      Company  Valuation ($B) Date Joined        Country           City  \
# 0  ByteDance           225.0  2017-04-07          China        Beijing
# 1     SpaceX           137.0  2012-12-01  United States      Hawthorne
# 2      SHEIN           100.0  2018-07-03          China       Shenzhen
# 3     Stripe            50.0  2014-01-23  United States  San Francisco
# 4      Canva            40.0  2018-01-08      Australia    Surry Hills
#
#                           Industry
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services

# %%
df.tail()
# Out:
#                   Company  Valuation ($B) Date Joined        Country  \
# 1203          LeadSquared             1.0  2022-06-21          India
# 1204            FourKites             1.0  2022-06-21  United States
# 1205          VulcanForms             1.0  2022-07-05  United States
# 1206          SingleStore             1.0  2022-07-12  United States
# 1207  Unstoppable Domains             1.0  2022-07-27  United States
#
#                City                             Industry
# 1203      Bengaluru         Internet software & services
# 1204        Chicago  Supply chain, logistics, & delivery
# 1205     Burlington  Supply chain, logistics, & delivery
# 1206  San Francisco          Data management & analytics
# 1207      Las Vegas         Internet software & services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208 entries, 0 to 1207
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1208 non-null   object
#  1   Valuation ($B)  1208 non-null   float64
#  2   Date Joined     1208 non-null   datetime64[ns]
#  3   Country         1208 non-null   object
#  4   City            1190 non-null   object
#  5   Industry        1208 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 37.8+ KB

# %%
df['Country'].value_counts()
# Out:
# United States           655
# China                   169
# India                    71
# United Kingdom           48
# Germany                  28
# France                   25
# Israel                   24
# Canada                   20
# Brazil                   16
# Singapore                14
# South Korea              14
# Mexico                    8
# Australia                 8
# Sweden                    7
# Indonesia                 7
# Netherlands               7
# Hong Kong                 7
# Switzerland               6
# Ireland                   6
# Japan                     6
# Spain                     5
# Norway                    4
# Finland                   4
# Turkey                    3
# United Arab Emirates      3
# Thailand                  3
# Belgium                   3
# Colombia                  3
# Greece                    2
# Italy                     2
# Austria                   2
# Lithuania                 2
# Estonia                   2
# ...

# %%
num_by_country = df['Country'].value_counts().head(10)
num_by_country.plot()
plt.show()

# %%
travel_unicors=df[df["Industry"]=="Travel"]
travel_unicors
# Out:
#            Company  Valuation ($B) Date Joined        Country       City  \
# 58           Navan            9.20  2018-11-08  United States  Palo Alto
# 62       OYO Rooms            9.00  2018-09-25          India   Gurugram
# 149         Hopper            5.00  2021-03-24         Canada   Montreal
# 285      Traveloka            3.00  2017-01-01      Indonesia    Jakarta
# 452       Mafengwo            2.00  2019-05-23          China    Beijing
# 490           Tier            2.00  2021-10-25        Germany     Berlin
# 621          TuJia            1.50  2015-06-17          China    Beijing
# 626        XiaoZhu            1.50  2017-11-01          China    Beijing
# 733          Klook            1.35  2018-08-07      Hong Kong    Central
# 760     TravelPerk            1.30  2022-01-12          Spain  Barcelona
# 872   GetYourGuide            1.10  2019-05-16        Germany     Berlin
# 990           Omio            1.00  2018-10-23        Germany     Berlin
# ...

# %%
turkish_unicors=df[df["Country"]=="Turkey"]
turkish_unicors
# Out:
#          Company  Valuation ($B) Date Joined Country      City  \
# 63         Getir            8.80  2021-03-26  Turkey  Istanbul
# 331  Dream Games            2.75  2021-06-30  Turkey  Istanbul
# 802      Insider            1.22  2022-02-28  Turkey  Istanbul
#
#                                 Industry
# 63   Supply chain, logistics, & delivery
# 331          Mobile & telecommunications
# 802         Internet software & services

# %%
Israeli_unicors=df[df["Country"]=="Israel"]
Israeli_unicors
# Out:
#                  Company  Valuation ($B) Date Joined Country           City  \
# 45                   Wiz           10.00  2021-03-17  Israel       Tel Aviv
# 142          Moon Active            5.00  2020-01-26  Israel       Tel Aviv
# 332    Transmit Security            2.74  2021-06-22  Israel       Tel Aviv
# 359        Cato Networks            2.50  2020-11-17  Israel       Tel Aviv
# 372            DriveNets            2.50  2021-01-27  Israel       Ra'anana
# 373                Hibob            2.45  2021-10-12  Israel       Tel Aviv
# 462               Earnix            2.00  2021-02-21  Israel     Giv'atayim
# 495            StarkWare            8.00  2021-11-17  Israel        Netanya
# 536           Lightricks            1.80  2019-07-31  Israel      Jerusalem
# 639         Next Silicon            1.50  2021-06-14  Israel       Tel Aviv
# 660             StoreDot            1.50  2022-01-04  Israel       Herzliya
# ...

# %%
Israeli_unicors_fintech=df[(df["Country"]=="Israel") & (df["Industry"]=="Fintech")]
Israeli_unicors_fintech
# Out:
#        Company  Valuation ($B) Date Joined Country           City Industry
# 462     Earnix             2.0  2021-02-21  Israel     Giv'atayim  Fintech
# 699  Liquidity             1.4  2023-02-20  Israel       Tel Aviv  Fintech
# 939    Vesttoo             1.0  2022-10-25  Israel  Tel Aviv-Yafo  Fintech

# %%
Israeli_unicors_fintech=df[(df["Country"]=="Israel") & (df["Industry"]=="Cybersecurity")]
Israeli_unicors_fintech
# Out:
#                 Company  Valuation ($B) Date Joined Country         City  \
# 45                  Wiz           10.00  2021-03-17  Israel     Tel Aviv
# 332   Transmit Security            2.74  2021-06-22  Israel     Tel Aviv
# 359       Cato Networks            2.50  2020-11-17  Israel     Tel Aviv
# 495           StarkWare            8.00  2021-11-17  Israel      Netanya
# 946        Perimeter 81            1.00  2022-06-06  Israel     Tel Aviv
# 1029      Aqua Security            1.00  2021-03-10  Israel    Ramat Gan
# 1157            Pentera            1.00  2022-01-11  Israel  Petah Tikva
#
#            Industry
# 45    Cybersecurity
# 332   Cybersecurity
# 359   Cybersecurity
# 495   Cybersecurity
# 946   Cybersecurity
# 1029  Cybersecurity
# 1157  Cybersecurity

# %%
Israeli_unicors_ai=df[(df["Country"]=="Israel") & (df["Industry"]=="Artificial intelligence")]
Israeli_unicors_ai
# Out:
#                 Company  Valuation ($B) Date Joined Country       City  \
# 536          Lightricks            1.80  2019-07-31  Israel  Jerusalem
# 883               Hailo            1.00  2021-10-12  Israel   Tel Aviv
# 924  OrCam Technologies            1.03  2018-02-20  Israel  Jerusalem
#
#                     Industry
# 536  Artificial intelligence
# 883  Artificial intelligence
# 924  Artificial intelligence

# %%
UAE=df[df["Country"]=="United Arab Emirates"]
UAE
# Out:
#                               Company  Valuation ($B) Date Joined  \
# 354                      Vista Global            2.50  2017-08-23
# 609                            Kitopi            1.55  2021-07-01
# 1009  Emerging Markets Property Group            1.00  2020-04-28
#
#                    Country   City                             Industry
# 354   United Arab Emirates  Dubai                                Other
# 609   United Arab Emirates  Dubai  Supply chain, logistics, & delivery
# 1009  United Arab Emirates  Dubai                                Other

# %%
canada = df[df["Country"]=="Canada"]
canada
# Out:
#              Company  Valuation ($B) Date Joined Country         City  \
# 82       Dapper Labs            7.60  2021-03-30  Canada    Vancouver
# 97         1Password            6.80  2021-07-08  Canada      Toronto
# 149           Hopper            5.00  2021-03-24  Canada     Montreal
# 185           SSENSE            4.15  2021-06-08  Canada     Montreal
# 198   PointClickCare            4.00  2021-01-07  Canada  Mississauga
# 273      Blockstream            3.20  2021-08-24  Canada    Vancouver
# 292       ApplyBoard            3.20  2020-05-05  Canada    Kitchener
# 464          Clearco            2.00  2021-04-20  Canada      Toronto
# 542          Trulioo            1.75  2021-06-07  Canada    Vancouver
# 582             Clio            1.60  2021-04-27  Canada      Burnaby
# 695          Figment            1.40  2021-12-20  Canada      Toronto
# 799            Nexii            1.23  2021-09-08  Canada    Vancouver
# ...

# %%
fintech_unicorns  = df[df["Industry"]=="Fintech"]
fintech_unicorns
# Out:
#            Company  Valuation ($B) Date Joined         Country           City  \
# 3           Stripe            50.0  2014-01-23   United States  San Francisco
# 5     Checkout.com            40.0  2019-05-02  United Kingdom         London
# 6          Revolut            33.0  2018-04-26  United Kingdom         London
# 10           Chime            25.0  2019-03-05   United States  San Francisco
# 21          Ripple            15.0  2019-12-20   United States  San Francisco
# ...            ...             ...         ...             ...            ...
# 1187        Oyster             1.0  2022-04-20   United States     Wilmington
# 1192        Taxfix             1.0  2022-04-28         Germany         Berlin
# 1193          Open             1.0  2022-05-02           India      Bengaluru
# 1195           Opn             1.0  2022-05-09           Japan          Tokyo
# 1197          Habi             1.0  2022-05-11        Colombia         Bogota
#
#      Industry
# 3     Fintech
# ...

# %%
ai_unicorns  = df[df["Industry"]=="Artificial intelligence"]
ai_unicorns
# Out:
#                Company  Valuation ($B) Date Joined        Country  \
# 0            ByteDance          225.00  2017-04-07          China
# 12              OpenAI           20.00  2019-07-22  United States
# 28               Faire           12.59  2019-10-30  United States
# 68             Pony.ai            8.50  2018-07-11  United States
# 70             Anduril            8.48  2019-09-11  United States
# ...                ...             ...         ...            ...
# 1087        Snorkel AI            1.00  2021-08-09  United States
# 1114  Weights & Biases            1.00  2021-10-13  United States
# 1119            Augury            1.00  2021-10-26  United States
# 1156         Placer.ai            1.00  2022-01-12  United States
# 1161         Betterfly            1.00  2022-02-01          Chile
#
#                City                 Industry
# 0           Beijing  Artificial intelligence
# 12    San Francisco  Artificial intelligence
# ...

# %%
ai_unicorns_USA  = df[(df["Industry"]=="Artificial intelligence") & (df["Country"]=="United States")]
print(len(ai_unicorns_USA))
ai_unicorns_USA
# Out:
# 49
#                   Company  Valuation ($B) Date Joined        Country  \
# 12                 OpenAI           20.00  2019-07-22  United States
# 28                  Faire           12.59  2019-10-30  United States
# 68                Pony.ai            8.50  2018-07-11  United States
# 70                Anduril            8.48  2019-09-11  United States
# 89               Scale AI            7.30  2019-08-05  United States
# 90                   Gong            7.25  2020-08-12  United States
# 96    Automation Anywhere            6.80  2018-07-02  United States
# 106             DataRobot            6.30  2019-07-29  United States
# 114                6Sense            5.20  2021-03-30  United States
# 148               Icertis            5.00  2019-07-17  United States
# 173             Anthropic            4.40  2023-02-03  United States
# 186              Dataminr            4.10  2018-06-04  United States
# ...

# %%
ai_unicorns_china  = df[(df["Industry"]=="Artificial intelligence") & (df["Country"]=="China")]
print(len(ai_unicorns_china))
ai_unicorns_china
# Out:
# 14
#                        Company  Valuation ($B) Date Joined Country      City  \
# 0                    ByteDance          225.00  2017-04-07   China   Beijing
# 137           Horizon Robotics            5.00  2019-02-27   China   Beijing
# 192                     MEGVII            4.00  2017-10-31   China   Beijing
# 419            YITU Technology            2.17  2018-03-08   China  Shanghai
# 449                  4Paradigm            2.00  2018-12-19   China   Beijing
# 478                     XtalPi            2.00  2021-08-11   China  Shenzhen
# 486  Black Sesame Technologies            2.00  2021-09-22   China  Shanghai
# 732        DeepBlue Technology            1.35  2018-04-16   China  Shanghai
# 744                   Unisound            1.31  2018-07-19   China   Beijing
# 815                      Aibee            1.20  2021-04-13   China   Beijing
# 847      Mininglamp Technology            1.19  2019-03-27   China   Beijing
# ...

# %%
ai_unicorns_around_the_world  = df[(df["Industry"]=="Artificial intelligence") & (df["Country"]!="China")& (df["Country"]!="United States") ]
print(len(ai_unicorns_around_the_world))
ai_unicorns_around_the_world
# Out:
# 18
#                          Company  Valuation ($B) Date Joined         Country  \
# 328                    Graphcore            2.77  2018-12-18  United Kingdom
# 349                        Unico            2.60  2021-08-03          Brazil
# 447           Preferred Networks            2.00  2018-05-17           Japan
# 487   Advance Intelligence Group            2.00  2021-09-23       Singapore
# 499                         Trax            2.00  2019-07-22       Singapore
# 536                   Lightricks            1.80  2019-07-31          Israel
# 578                      Afiniti            1.60  2017-04-14         Bermuda
# 663                       Veriff            1.50  2022-01-26         Estonia
# 819                  Ada Support            1.20  2021-05-07          Canada
# 883                        Hailo            1.00  2021-10-12          Israel
# 924           OrCam Technologies            1.03  2018-02-20          Israel
# ...

# %%
hardware_unicorns  = df[(df["Industry"]=="Hardware") & (df["Country"]=="United States")]
hardware_unicorns
# Out:
#                Company  Valuation ($B) Date Joined        Country  \
# 207   Cerebras Systems            4.00  2018-11-14  United States
# 250       Flock Safety            3.50  2021-07-13  United States
# 269        Astera Labs            3.20  2022-11-17  United States
# 280         PsiQuantum            3.15  2021-07-27  United States
# 368             SiFive            2.50  2022-03-16  United States
# 380             Carbon            2.40  2015-08-20  United States
# 448           Formlabs            2.00  2018-08-01  United States
# 489         Magic Leap            2.00  2014-10-21  United States
# 537          Opentrons            1.80  2021-09-23  United States
# 577          Infinidat            1.60  2015-04-29  United States
# 603               Icon            1.57  2022-02-18  United States
# 921            Density            1.05  2021-11-10  United States
# 925              Ample            1.02  2021-11-11  United States
# ...

# %%
len(hardware_unicorns )
# Out:
# 40

# %%
hardware_unicorns_in_usa = df[(df["Industry"]=="Hardware") & (df["Country"]=="United States")]
print(len(hardware_unicorns))
hardware_unicorns_in_usa
# Out:
# 14
#                Company  Valuation ($B) Date Joined        Country  \
# 207   Cerebras Systems            4.00  2018-11-14  United States
# 250       Flock Safety            3.50  2021-07-13  United States
# 269        Astera Labs            3.20  2022-11-17  United States
# 280         PsiQuantum            3.15  2021-07-27  United States
# 368             SiFive            2.50  2022-03-16  United States
# 380             Carbon            2.40  2015-08-20  United States
# 448           Formlabs            2.00  2018-08-01  United States
# 489         Magic Leap            2.00  2014-10-21  United States
# 537          Opentrons            1.80  2021-09-23  United States
# 577          Infinidat            1.60  2015-04-29  United States
# 603               Icon            1.57  2022-02-18  United States
# 921            Density            1.05  2021-11-10  United States
# 925              Ample            1.02  2021-11-11  United States
# ...

# %%
hardware_unicorns_in_china = df[(df["Industry"]=="Hardware") & (df["Country"]=="China")]
print(len(hardware_unicorns_in_china))
hardware_unicorns_in_china
# Out:
# 18
#                      Company  Valuation ($B) Date Joined Country       City  \
# 17           DJI Innovations           15.00  2015-01-23   China   Shenzhen
# 31      Bitmain Technologies           12.00  2018-07-06   China    Beijing
# 111       Royole Corporation            6.00  2015-08-18   China   Shenzhen
# 158                  Chipone            4.73  2021-12-16   China    Beijing
# 170          UBTECH Robotics            4.58  2016-07-25   China   Shenzhen
# 395         Biren Technology            2.32  2020-08-18   China   Shanghai
# 513                    Geek+            2.00  2018-11-21   China    Beijing
# 607           Iluvatar CoreX            1.55  2021-03-01   China   Shanghai
# 682                   Coocaa            1.45  2018-03-16   China   Shenzhen
# 737      Jaguar Microsystems            1.34  2022-06-23   China   Shenzhen
# 779   Greater Bay Technology            1.26  2022-04-02   China  Guangzhou
# ...

# %%
hardware_unicorns_not_in_usa_or_china  = df[(df["Industry"]=="Hardware") & (df["Country"]!="United States")& (df["Country"]!="China")]
hardware_unicorns_not_in_usa_or_china
# Out:
#             Company  Valuation ($B) Date Joined         Country       City  \
# 39    Global Switch            11.1  2016-12-22  United Kingdom     London
# 500          Exotec             2.0  2022-01-17          France      Croix
# 638          Ledger             1.5  2021-06-10          France      Paris
# 639    Next Silicon             1.5  2021-06-14          Israel   Tel Aviv
# 935          Xanadu             1.0  2022-11-09          Canada    Toronto
# 992         BitFury             1.0  2018-11-06     Netherlands  Amsterdam
# 1094   Agile Robots             1.0  2021-09-09         Germany     Munich
# 1202         Vayyar             1.0  2022-06-06          Israel      Yehud
#
#       Industry
# 39    Hardware
# 500   Hardware
# 638   Hardware
# 639   Hardware
# 935   Hardware
# 992   Hardware
# 1094  Hardware
# 1202  Hardware
